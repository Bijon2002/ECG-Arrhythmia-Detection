# %% [markdown]
# <a href="https://colab.research.google.com/github/Bijon2002/ECG-Arrhythmia-Detection/blob/main/ECG_Arrhythmia_Detection_Bijosilin_Marisilin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Clone my repo https://github.com/Bijon2002/ECG-Arrhythmia-Detection.git**

# %%
# !git clone https://github.com/Bijon2002/ECG-Arrhythmia-Detection.git
# Out:
# Cloning into 'ECG-Arrhythmia-Detection'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 125 (delta 33), reused 112 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (125/125), 10.04 MiB | 38.06 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %% [markdown]
# **Enter the Project Folder**

# %%
import os
os.chdir('ECG-Arrhythmia-Detection')
print("Currently in:", os.getcwd())
# Out:
# Currently in: /content/ECG-Arrhythmia-Detection

# %% [markdown]
# **install the project dependencies**

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 106.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 123.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 78.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.7/676.7 kB 45.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 58.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.3
#     Uninstalling tqdm-4.67.3:
#       Successfully uninstalled tqdm-4.67.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ...

# %% [markdown]
# **Getting the data**

# %%
# !python src/download_data.py
# Out:
# ...
# This might take a few minutes (approx 72 MB)...
# Generating record list for: 100
# Generating record list for: 101
# Generating record list for: 102
# Generating record list for: 103
# Generating record list for: 104
# Generating record list for: 105
# Generating record list for: 106
# Generating record list for: 107
# Generating record list for: 108
# Generating record list for: 109
# Generating record list for: 111
# Generating record list for: 112
# Generating record list for: 113
# Generating record list for: 114
# Generating record list for: 115
# Generating record list for: 116
# Generating record list for: 117
# Generating record list for: 118
# Generating record list for: 119
# Generating record list for: 121
# Generating record list for: 122
# Generating record list for: 123
# Generating record list for: 124
# Generating record list for: 200
# Generating record list for: 201
# Generating record list for: 202
# Generating record list for: 203
# ...

# %% [markdown]
# verify my whole pipeline is working

# %%
# !python test_setup.py
# Out:
# Testing ECG setup...
#
# Utils ready!
# ? Utils import works
# ? Config import works
# ? Device: cuda
# ? Classes: 5
#
# ?? All tests passed! Setup is working!

# %% [markdown]
# **preprocessing**

# %%
# !python src/preprocess.py
# Out:
# Fetching record list for MIT-BIH dataset...
# Dataset already downloaded in data/raw/!
# Processing 48 patient records (Filtering & Slicing)...
#
#
# Extraction complete! Successfully extracted 109438 individual heartbeats.
#
# Final Data Matrix Shape (X): (109438, 360)
# Final Labels Shape (y): (109438,)
#
# Splitting data into 80% Training and 20% Testing...
# Training Set: 87550 heartbeats
# Testing Set: 21888 heartbeats
#
# Saving highly compressed data to data/processed/...
# Data saved successfully! Phase 2 is complete.

# %% [markdown]
# **training**

# %%
# !python src/train.py
# Out:
# Loading highly compressed heartbeats...
# Loaded 87550 training beats.
# Computed Class Weights: tensor([ 0.2416,  7.8697,  3.0252, 27.2741,  2.7232])
#
# --- Training Model 1/5 ---
# Epoch [1/5] completed. Average Loss: 0.3925
# Epoch [2/5] completed. Average Loss: 0.2322
# Epoch [3/5] completed. Average Loss: 0.1799
# Epoch [4/5] completed. Average Loss: 0.1462
# Epoch [5/5] completed. Average Loss: 0.1311
# ✅ Model 1 saved to: /content/ECG-Arrhythmia-Detection/models/ecg_model_v1.pth
#
# --- Training Model 2/5 ---
# Epoch [1/5] completed. Average Loss: 0.3994
# Epoch [2/5] completed. Average Loss: 0.2407
# Epoch [3/5] completed. Average Loss: 0.1875
# Epoch [4/5] completed. Average Loss: 0.1513
# Epoch [5/5] completed. Average Loss: 0.1331
# ✅ Model 2 saved to: /content/ECG-Arrhythmia-Detection/models/ecg_model_v2.pth
#
# --- Training Model 3/5 ---
# Epoch [1/5] completed. Average Loss: 0.3924
# Epoch [2/5] completed. Average Loss: 0.2330
# ...

# %% [markdown]
# **Temperature Scaling calibration values**

# %%
# !python src/calibrate.py
# Out:
# Loading test data for Temperature Scaling Calibration...
#
# Calibrating Model 1...
# Optimal Temperature (T) for Model 1: 1.1893
#
# Calibrating Model 2...
# Optimal Temperature (T) for Model 2: 1.0976
#
# Calibrating Model 3...
# Optimal Temperature (T) for Model 3: 1.1215
#
# Calibrating Model 4...
# Optimal Temperature (T) for Model 4: 1.1587
#
# Calibrating Model 5...
# Optimal Temperature (T) for Model 5: 1.1849
#
# ✅ All ensemble models successfully calibrated.

# %% [markdown]
# **install the tunnel tool**

# %%
# !npm install -g localtunnel
# Out:
# ⠙^C

# %% [markdown]
# ** run  API and open the tunnel **

# %%
# !nohup python api.py &
# !npx localtunnel --port 8000
# Out:
# nohup: appending output to 'nohup.out'
# ⠙⠹⠸⠼⠴⠦your url is: https://every-olives-sniff.loca.lt
